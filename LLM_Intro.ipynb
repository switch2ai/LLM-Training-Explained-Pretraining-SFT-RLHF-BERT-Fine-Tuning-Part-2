# %%
# LLM : Large Language Model

# Language Model :

# %%
## Why they are large?
-- No. of parameters
-- Training data

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

# %%
pipeline = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipeline("Once upon a time")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
pipeline("What is capital of India?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %% [markdown]
# ###How to train LLM?

# %%
1. Pre-training : (Next word Prediction)

2. Supervised FineTuning (SFT) :

3. Reinforcement Learning from Human Feedback (RLHF) :

# %%
## Decoder of transformer :

# %%
# 1. Pre-training : (Next word Prediction)

"We are learning LLM"

We           --> are
We are       --> learning
We are learning --> LLM

## Model will Learn :
-- Language Understnding (Syntax, Grammer, ...)
-- Facts

## Base/ Foundation Model :

# %%
# 2. Supervised FineTuning (SFT) :

Prompt                                      Response
--------------------------------------------------------
What is capital of India?                   New Delhi
define ML                                   ML is a ....
write a code for ..                         ...

# %%
# 3. Reinforcement Learning from Human Feedback (RLHF) :
-- Align model with human value

# %%
Prompt1   -->  Model (LLM)   --> res1, res2, res3

Human Evaluator : res1   : 50
                  res2   : 100
                  res3   : 10

Reward Model : Give points to generated response
response = point

Input --> Model (LLM)  --> Response --> Reward Model  --> Points

# %%
from IPython.display import Image
Image("/content/LLM_Training.png")
